# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.68.3)
# Requirement already satisfied: colorama in C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
import sys
# !{sys.executable} -m pip show nltk
# Out:
# Name: nltk
# Version: 3.9.4
# Summary: Natural Language Toolkit
# Home-page: https://www.nltk.org/
# Author: NLTK Team
# Author-email: nltk.team@gmail.com
# License: Apache License, Version 2.0
# Location: c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: click, joblib, regex, tqdm
# Required-by:

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe
# 3.12.9 (tags/v3.12.9:fdb8142, Feb  4 2025, 15:27:58) [MSC v.1942 64 bit (AMD64)]

# %%
import sys

# !{sys.executable} -m pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.4.1)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl (277 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.68.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, nltk
# Successfully installed joblib-1.5.3 nltk-3.9.4 regex-2026.5.9 tqdm-4.68.3
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
document=sent_tokenize(corpus)
for i in document:
    print(i)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
from nltk.data import find

try:
    print(find("tokenizers/punkt"))
except Exception as e:
    print(e)

try:
    print(find("tokenizers/punkt_tab"))
except Exception as e:
    print(e)
# Out:
# C:\Users\HP\AppData\Roaming\nltk_data\tokenizers\punkt
# C:\Users\HP\AppData\Roaming\nltk_data\tokenizers\punkt_tab

# %%
from nltk.tokenize import sent_tokenize

corpus = """
Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course!
"""

document = sent_tokenize(corpus)

for i in document:
    print(i)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!

# %%
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
document = sent_tokenize(corpus)

for i in document:
    print(i)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
from nltk.tokenize import word_tokenize
for i in word_tokenize(corpus):
    print(i)
# Out:
# Hello
# Welcome
# ,
# to
# Krish
# Naik
# 's
# NLP
# Tutorials
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %% [markdown]
# Raw Text
#    ↓
# sent_tokenize()
#    ↓
# Sentences
#    ↓
# word_tokenize()
#    ↓
# Words/Tokens
#    ↓
# Stopwords Removal
#    ↓
# Stemming/Lemmatization
#    ↓
# Vectorization (BoW, TF-IDF, Word2Vec)
#    ↓
# Machine Learning Model
